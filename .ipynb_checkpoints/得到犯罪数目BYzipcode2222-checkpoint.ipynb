# %%
#!/usr/bin/python

import json
import urllib2
import base64
import zlib

# Overall WS Access Variables
dbsAlias = 'HackSys'
wsHost = '153.64.73.150'
wsPort =  '1080'
path = '/tdrest/systems/' + dbsAlias + '/queries'

def rest_request ( query ,wsUser,wsPass):
    url = 'http://' + wsHost + ':' + wsPort + path
   
    headers={}
    headers['Content-Type'] = 'application/json'
    headers['Accept'] = 'application/vnd.com.teradata.rest-v1.0+json'
    headers['Authorization'] = "Basic %s" % base64.encodestring('%s:%s' % (wsUser, wsPass)).replace('\n', '');

    # Set query bands
    queryBands = {}
    queryBands['applicationName'] = 'MyApp'
    queryBands['version'] = '1.0'

    # Set request fields. including SQL
    data = {}
    data['query'] = query
    data['queryBands'] = queryBands
    data['format'] = 'array'

    # Build request.
    request = urllib2.Request(url, json.dumps(data), headers)

    #Submit request
    try:
        response = urllib2.urlopen(request);
        # Check if result have been compressed.
        if response.info().get('Content-Encoding') == 'gzip':
            response = zlib.decompress(response.read(), 16+zlib.MAX_WBITS)
        else:
            response = response.read();
    except urllib2.HTTPError, e:
        print 'HTTPError = ' + str(e.code)
        response = e.read();
    except urllib2.URLError, e:
        print 'URLError = ' + str(e.reason)
        response = e.read();

    # Parse response to confirm value JSON.
    results = json.loads(response);

#     print json.dumps(results, indent=4, sort_keys=True) 

    return results;

def perform_query( query, wsUser, wsPass ):
    results = rest_request(query, wsUser, wsPass)
    
    return results;

wsUser = 'hack_user14'
wsPass = 'tdhackathon'
ret = perform_query ( 'select * from crime_data.portland_crime', wsUser, wsPass)

# %%
ret['queryDuration']
ret
# Out:
# {u'queryDuration': 818,
#  u'queueDuration': 531,
#  u'results': [{u'data': [[11182959,
#      1153540800000,
#      62700000,
#      u'Vandalism',
#      u'4701-4799 block of N INTERSTATE AVE, PORTLAND, OR 97217',
#      u'OVERLOOK',
#      u'PORTLAND PREC NO',
#      u'570',
#      7643159.11714,
#      696665.20929],
#     [11116476,
#      1136869200000,
#      76800000,
#      u'Vandalism',
#      u'6801-6899 block of N MARYLAND AVE, PORTLAND, OR 97217',
#      u'ARBOR LODGE',
#      u'PORTLAND PREC NO',
#      u'560',
#      7643676.52786,
#      702091.23524],
#     [11629503,
#      1221278400000,
#      28860000,
#      u'Aggravated Assault',
#      u'SE OAK ST and SE 81ST AVE, PORTLAND, OR 97215',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'902',
#      7668905.21786,
#      682640.67071],
#     [11186684,
#      1155182400000,
#      74820000,
#      u'Vandalism',
#      u'N CHAUTAUQUA BLVD and N NEWARK ST, PORTLAND, OR 97217',
#      u'KENTON',
#      u'PORTLAND PREC NO',
#      u'550',
#      7637596.08214,
#      708972.66],
#     [11226514,
#      1165986000000,
#      24840000,
#      u'Larceny',
#      u'301-399 block of SW 10TH AVE, PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7643153.51762,
#      684237.02976],
#     [11226540,
#      1166072400000,
#      54000000,
#      u'Motor Vehicle Theft',
#      u'200-298 block of SW TAYLOR ST, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644587.44024,
#      681966.16881],
#     [11562006,
#      1204952400000,
#      26460000,
#      u'Motor Vehicle Theft',
#      u'15700-15798 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7688948.625,
#      676362.58167],
#     [11137654,
#      1142485200000,
#      72000000,
#      u'Larceny',
#      u'NW WESTOVER RD and NW 23RD AVE, PORTLAND, OR 97210',
#      u'NORTHWEST',
#      u'PORTLAND PREC CE',
#      u'860',
#      7638736.51929,
#      684822.62786],
#     [11127818,
#      1139893200000,
#      70440000,
#      u'Larceny',
#      u'9701-9899 block of N SMITH ST, PORTLAND, OR 97203',
#      u'ST JOHNS',
#      u'PORTLAND PREC NO',
#      u'520',
#      7624621.30833,
#      712247.95238],
#     [11179710,
#      1151640000000,
#      75660000,
#      u'Arson',
#      u'VENTURA PARK',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'951',
#      7677979.49002,
#      682128.92687],
#     [11573620,
#      1207886400000,
#      54000000,
#      u'Motor Vehicle Theft',
#      u'4401-4599 block of SE BOISE ST, PORTLAND, OR 97206',
#      u'CRSTN-KENILWTH',
#      u'PORTLAND PREC EA',
#      u'911',
#      7659334.25905,
#      672848.9969],
#     [11210431,
#      1161316800000,
#      69840000,
#      u'Larceny',
#      u'500-1098 block of SE 139TH AVE, PORTLAND, OR 97233',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'952',
#      7684135.46738,
#      681830.79167],
#     [11214673,
#      1162357200000,
#      77760000,
#      u'Embezzlement',
#      u'101-199 block of SW COLUMBIA ST, PORTLAND, OR 97258',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7644333.00095,
#      680664.70429],
#     [11161430,
#      1148702400000,
#      67020000,
#      u'Larceny',
#      u'8001-8199 block of SE TAYLOR ST, PORTLAND, OR 97215',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'902',
#      7668615.79595,
#      680913.8181],
#     [11591483,
#      1212292800000,
#      73980000,
#      u'Larceny',
#      u'6300-6598 block of SE 32ND AVE, PORTLAND, OR 97202',
#      u'EASTMORELAND',
#      u'PORTLAND PREC CE',
#      u'742',
#      7655715.44071,
#      667031.44024],
#     [11114385,
#      1136350800000,
#      63300000,
#      u'Larceny',
#      u'200-298 block of SW YAMHILL ST, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644686.56786,
#      682206.68786],
#     [11175042,
#      1152849600000,
#      68580000,
#      u'Fraud',
#      u'5301-5499 block of SW MACADAM AVE, PORTLAND, OR 97239',
#      u'SOUTH PORTLAND',
#      u'PORTLAND PREC CE',
#      u'890',
#      7644314.01881,
#      670434.03524],
#     [11220268,
#      1164085200000,
#      101220000,
#      u'Larceny',
#      u'2700-2898 block of NE 57TH AVE, PORTLAND, OR 97213',
#      u'ROSE CITY PARK',
#      u'PORTLAND PREC NO',
#      u'680',
#      7662950.19595,
#      690809.70381],
#     [11570809,
#      1207108800000,
#      93900000,
#      u'Motor Vehicle Theft',
#      u'1001-1099 block of NE ONEONTA ST, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7650217.83881,
#      702242.49286],
#     [11184830,
#      1155182400000,
#      65340000,
#      u'Fraud',
#      u'4501-4999 block of SE 59TH AVE, PORTLAND, OR 97206',
#      u'WOODSTOCK',
#      u'PORTLAND PREC EA',
#      u'921',
#      7662966.85024,
#      671858.07595],
#     [11149281,
#      1145592000000,
#      46800000,
#      u'Larceny',
#      u'1831-1869 block of SE 157TH DR, PORTLAND, OR 97233',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'961',
#      7688579.38167,
#      678711.5781],
#     [11204742,
#      1160366400000,
#      20640000,
#      u'Drugs',
#      u'NE LOMBARD ST and NE MARTIN LUTHER KING BLVD, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7648746.95381,
#      703947.99405],
#     [11598084,
#      1213761600000,
#      91800000,
#      u'Liquor Laws',
#      u'WATERFRONT PARK',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645665.13826,
#      682757.65683],
#     [11133010,
#      1141275600000,
#      75240000,
#      u'Larceny',
#      u'4000 Block SE 82nd Ave',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669095.393,
#      672751.084],
#     [11133665,
#      1141275600000,
#      101220000,
#      u'Larceny',
#      u'16000-16148 block of SE STARK ST, PORTLAND, OR 97233',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'961',
#      7689763.58429,
#      681708.50857],
#     [11188823,
#      1155614400000,
#      93900000,
#      u'Assault, Simple',
#      u'SE DIVISION ST and SE 115TH AVE, PORTLAND, OR 97216',
#      u'MILL PARK',
#      u'PORTLAND PREC EA',
#      u'951',
#      7677905.73786,
#      676540.9969],
#     [11655410,
#      1227157200000,
#      68400000,
#      u'Larceny',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11143438,
#      1144036800000,
#      79980000,
#      u'Larceny',
#      u'2700-2728 block of SW ENGLISH CT, PORTLAND, OR 97201',
#      u'SOUTHWEST HILLS',
#      u'PORTLAND PREC CE',
#      u'860',
#      7635511.10976,
#      677887.12976],
#     [11191561,
#      1156305600000,
#      65280000,
#      u'Disorderly Conduct',
#      u'700-798 block of SW BROADWAY , PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7643500.12286,
#      682976.29095],
#     [11231549,
#      1167454800000,
#      65400000,
#      u'Larceny',
#      u'9000-9198 block of SE POWELL BLVD, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7671227.96714,
#      674241.10667],
#     [11560562,
#      1204606800000,
#      25800000,
#      u'Drugs',
#      u'NW FLANDERS ST and NW 4TH AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7644877.06,
#      685348.14905],
#     [11230866,
#      1167282000000,
#      21600000,
#      u'Vandalism',
#      u'600-698 block of NE MORGAN ST, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7649232.75833,
#      702914.44119],
#     [11191498,
#      1156219200000,
#      61560000,
#      u'Larceny',
#      u'N KERBY AVE and N WHEELER PL, PORTLAND, OR 97227',
#      u'ELIOT',
#      u'PORTLAND PREC NO',
#      u'590',
#      7645684.63714,
#      689235.87714],
#     [11192165,
#      1156564800000,
#      52740000,
#      u'Burglary',
#      u'2810-2898 block of SE 82ND AVE, PORTLAND, OR 97266',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669198.42024,
#      676024.17214],
#     [11539746,
#      1199250000000,
#      51300000,
#      u'Vandalism',
#      u'3000-3098 block of SE 82ND AVE, PORTLAND, OR 97266',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669187.11476,
#      675428.39071],
#     [11162246,
#      1148961600000,
#      62640000,
#      u'Larceny',
#      u'6600-6998 block of SE 21ST AVE, PORTLAND, OR 97202',
#      u'SELLWD-MORELAND',
#      u'PORTLAND PREC CE',
#      u'742',
#      7652205.57381,
#      666867.47667],
#     [11115420,
#      1136523600000,
#      102780000,
#      u'Larceny',
#      u'3801-3849 block of SE HAWTHORNE BLVD, PORTLAND, OR 97214',
#      u'SUNNYSIDE',
#      u'PORTLAND PREC CE',
#      u'720',
#      7657557.05714,
#      679941.21333],
#     [11168210,
#      1150344000000,
#      85080000,
#      u'Vandalism',
#      u'8900-9008 block of N CALVERT AVE, PORTLAND, OR 97217',
#      u'KENTON',
#      u'PORTLAND PREC NO',
#      u'550',
#      7639928.85595,
#      707769.14405],
#     [11632573,
#      1221883200000,
#      74460000,
#      u'Aggravated Assault',
#      u'4801-4999 block of NE 55TH AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7662476.4881,
#      696537.09524],
#     [11184163,
#      1154404800000,
#      97200000,
#      u'Disorderly Conduct',
#      u'SW MORRISON ST and SW 5TH AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644018.02167,
#      682763.07429],
#     [11188052,
#      1155441600000,
#      64620000,
#      u'Larceny',
#      u'1101-1199 block of SE MARKET ST, PORTLAND, OR 97214',
#      u'HOSFRD-ABRNETHY',
#      u'PORTLAND PREC CE',
#      u'730',
#      7649801.81714,
#      679686.01929],
#     [11191846,
#      1156478400000,
#      41880000,
#      u'Larceny',
#      u'7001-7299 block of N ARMOUR ST, PORTLAND, OR 97203',
#      u'ST JOHNS',
#      u'PORTLAND PREC NO',
#      u'520',
#      7630147.56286,
#      712152.11619],
#     [11649301,
#      1225774800000,
#      49140000,
#      u'Larceny',
#      u'701-899 block of NW NAITO PKWY, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645191.96905,
#      686161.79762],
#     [11117089,
#      1137042000000,
#      51300000,
#      u'Larceny',
#      u'6300-6498 block of NE GRAND AVE, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7648906.17929,
#      700665.94619],
#     [11172129,
#      1151380800000,
#      76560000,
#      u'Fraud',
#      u'1401-1499 block of NE HALSEY ST, PORTLAND, OR 97232',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7650841.85524,
#      687983.53024],
#     [11121112,
#      1138165200000,
#      94200000,
#      u'Assault, Simple',
#      u'NW 4TH AVE and W BURNSIDE ST, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7644875.66405,
#      684308.09024],
#     [11574970,
#      1208232000000,
#      56040000,
#      u'Drugs',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11143183,
#      1144123200000,
#      87300000,
#      u'Drugs',
#      u'2000-2498 block of SE 82ND AVE, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669262.42119,
#      678285.25119],
#     [11203982,
#      1160193600000,
#      50700000,
#      u'Aggravated Assault',
#      u'SW WASHINGTON ST and SW 5TH AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644215.99619,
#      683243.91619],
#     [11186747,
#      1155009600000,
#      85500000,
#      u'Liquor Laws',
#      u'WATERFRONT PARK',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645665.13826,
#      682757.65683],
#     [11556018,
#      1203483600000,
#      47640000,
#      u'Larceny',
#      u'11410-11498 block of SE SALMON ST, PORTLAND, OR 97216',
#      u'MILL PARK',
#      u'PORTLAND PREC EA',
#      u'951',
#      7677753.3119,
#      680403.98405],
#     [11154789,
#      1146283200000,
#      44220000,
#      u'Vandalism',
#      u'5601-5799 block of N CECELIA ST, PORTLAND, OR 97203',
#      u'PORTSMOUTH',
#      u'PORTLAND PREC NO',
#      u'530',
#      7632822.6431,
#      710044.4181],
#     [11116110,
#      1136782800000,
#      67860000,
#      u'Motor Vehicle Theft',
#      u'13801-14309 block of NE AIRPORT WAY, PORTLAND, OR 97230',
#      u'ARGAY',
#      u'PORTLAND PREC NO',
#      u'652',
#      7684497.6869,
#      697435.29619],
#     [11122514,
#      1138251600000,
#      45900000,
#      u'Fraud',
#      u'15400-15598 block of SE OGDEN DR, PORTLAND, OR 97236',
#      u'PLEASANT VALLEY',
#      u'PORTLAND PREC EA',
#      u'990',
#      7687850.4819,
#      664181.83714],
#     [11543893,
#      1200286800000,
#      48840000,
#      u'Larceny',
#      u'6101-6299 block of SE 103RD PL, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'982',
#      7674683.09929,
#      667201.6619],
#     [11159934,
#      1148356800000,
#      63720000,
#      u'Motor Vehicle Theft',
#      u'4201-4299 block of SE 90TH AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7671210.66976,
#      672206.69381],
#     [11173453,
#      1151726400000,
#      57000000,
#      u'Larceny',
#      u'NE FREMONT ST and NE MARTIN LUTHER KING BLVD, PORTLAND, OR 97212',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648402.80405,
#      693395.71],
#     [11210282,
#      1161921600000,
#      24000000,
#      u'Vandalism',
#      u'NW FLANDERS ST and NW 3RD AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645137.06024,
#      685347.88976],
#     [11599498,
#      1214193600000,
#      67620000,
#      u'Larceny',
#      u'7200-7498 block of N INTERSTATE AVE, PORTLAND, OR 97217',
#      u'ARBOR LODGE',
#      u'PORTLAND PREC NO',
#      u'560',
#      7643417.09595,
#      703386.06119],
#     [11116196,
#      1136264400000,
#      75480000,
#      u'Vandalism',
#      u'1900-2098 block of NE BROADWAY , PORTLAND, OR 97232',
#      u'SULLIVANS GULCH',
#      u'PORTLAND PREC NO',
#      u'670',
#      7652097.65476,
#      688465.43286],
#     [11125253,
#      1139288400000,
#      55800000,
#      u'Trespass',
#      u'1021-1199 block of NE 122ND AVE, PORTLAND, OR 97230',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'941',
#      7679965.80524,
#      685997.96619],
#     [11135568,
#      1141880400000,
#      55500000,
#      u'Liquor Laws',
#      u'UNDER BURNSIDE BRG WEST',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645969.45492,
#      684272.37317],
#     [11597553,
#      1213761600000,
#      21720000,
#      u'Liquor Laws',
#      u'SW PINE ST and SW 3RD AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645024.59619,
#      683753.91786],
#     [11172933,
#      1151553600000,
#      93960000,
#      u'Prostitution',
#      u'SE MILL ST and SE 82ND AVE, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669286.35429,
#      679188.95405],
#     [11141629,
#      1143694800000,
#      60300000,
#      u'Larceny',
#      u'SE CESAR E CHAVEZ BLVD and SE HAWTHORNE BLVD, PORTLAND, OR 97214',
#      u'SUNNYSIDE',
#      u'PORTLAND PREC EA',
#      u'901',
#      7657982.6869,
#      679926.73619],
#     [11129340,
#      1140411600000,
#      18000000,
#      u'Vandalism',
#      u'2900-3298 block of SE 66TH AVE, PORTLAND, OR 97206',
#      u'SOUTH TABOR',
#      u'PORTLAND PREC EA',
#      u'912',
#      7664859.04429,
#      675879.31619],
#     [11543699,
#      1200200400000,
#      77040000,
#      u'Vandalism',
#      u'801-899 block of SE 51ST AVE, PORTLAND, OR 97215',
#      u'MT TABOR',
#      u'PORTLAND PREC EA',
#      u'901',
#      7661211.7281,
#      681825.57071],
#     [11187177,
#      1155268800000,
#      89040000,
#      u'Larceny',
#      u'4701-4799 block of NE 79TH AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'642',
#      7669088.65595,
#      696168.52333],
#     [11150681,
#      1145937600000,
#      52440000,
#      u'Larceny',
#      u'300-398 block of NW 5TH AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7644616.79976,
#      685088.40476],
#     [11196981,
#      1157774400000,
#      39900000,
#      u'Trespass',
#      u'7900-7998 block of NE THOMPSON ST, PORTLAND, OR 97213',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7668687.07714,
#      689506.62381],
#     [11569803,
#      1206936000000,
#      35520000,
#      u'Disorderly Conduct',
#      u'SE KNIGHT ST and SE 80TH AVE, PORTLAND, OR 97206',
#      u'MT SCOTT-ARLETA',
#      u'PORTLAND PREC EA',
#      u'922',
#      7668252.2181,
#      668082.94524],
#     [11208029,
#      1161230400000,
#      74580000,
#      u'Stolen Property',
#      u'SE FOSTER RD and SE 56TH AVE, PORTLAND, OR 97206',
#      u'FOSTER-POWELL',
#      u'PORTLAND PREC EA',
#      u'911',
#      7662280.21214,
#      673219.65238],
#     [11150727,
#      1145678400000,
#      67500000,
#      u'Trespass',
#      u'510-598 block of NW 3RD AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645134.19095,
#      685650.7269],
#     [11175211,
#      1151640000000,
#      62940000,
#      u'Burglary',
#      u'5101-5299 block of SE 30TH AVE, PORTLAND, OR 97202',
#      u'REED',
#      u'PORTLAND PREC CE',
#      u'741',
#      7654784.98524,
#      670682.41024],
#     [11652119,
#      1226466000000,
#      38700000,
#      u'Larceny',
#      u'13901-14099 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'952',
#      7684015.12619,
#      676358.8531],
#     [11163672,
#      1149220800000,
#      98040000,
#      u'Larceny',
#      u'1500-1598 block of NE MULTNOMAH ST, PORTLAND, OR 97232',
#      u'SULLIVANS GULCH',
#      u'PORTLAND PREC NO',
#      u'670',
#      7651076.63857,
#      687196.12929],
#     [11188793,
#      1155700800000,
#      100320000,
#      u'Drugs',
#      u'SE WASHINGTON ST and SE 82ND AVE, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669266.73976,
#      681949.04976],
#     [11221309,
#      1164603600000,
#      53760000,
#      u'Motor Vehicle Theft',
#      u'700-748 block of NE MORGAN ST, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7649492.62714,
#      702907.31238],
#     [11602925,
#      1214971200000,
#      85200000,
#      u'Larceny',
#      u'4740-4798 block of N VANDERBILT ST, PORTLAND, OR 97203',
#      u'PORTSMOUTH',
#      u'PORTLAND PREC NO',
#      u'530',
#      7634784.33595,
#      705504.07024],
#     [11196026,
#      1157428800000,
#      78180000,
#      u'Burglary',
#      u'0611-0619 block of SW PALATINE HILL RD, PORTLAND, OR 97219',
#      u'COLLINS VIEW',
#      u'PORTLAND PREC CE',
#      u'890',
#      7644641.9069,
#      658005.24429],
#     [11190445,
#      1156132800000,
#      64560000,
#      u'Vandalism',
#      u'1900-2098 block of SE CLATSOP ST, PORTLAND, OR 97202',
#      u'SELLWD-MORELAND',
#      u'PORTLAND PREC CE',
#      u'742',
#      7651788.3981,
#      661383.04],
#     [11222133,
#      1164690000000,
#      77520000,
#      u'Burglary',
#      u'2500-2948 block of SE 118TH AVE, PORTLAND, OR 97266',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'972',
#      7678572.41119,
#      676513.59214],
#     [11614072,
#      1217563200000,
#      76800000,
#      u'Larceny',
#      u'701-799 block of SW 16TH AVE, PORTLAND, OR 97205',
#      u'GOOSE HOLLOW',
#      u'PORTLAND PREC CE',
#      u'842',
#      7641337.48333,
#      683867.28024],
#     [11130435,
#      1140670800000,
#      63000000,
#      u'Vandalism',
#      u'NE ALBERTA ST and NE 31ST AVE, PORTLAND, OR 97211',
#      u'CONCORDIA',
#      u'PORTLAND PREC NO',
#      u'620',
#      7655616.11786,
#      697127.83071],
#     [11217002,
#      1163480400000,
#      43800000,
#      u'Motor Vehicle Theft',
#      u'11911-11939 block of N CENTER AVE, PORTLAND, OR 97217',
#      u'HAYDEN ISLAND',
#      u'PORTLAND PREC NO',
#      u'540',
#      7644091.74667,
#      715623.69262],
#     [11187609,
#      1155355200000,
#      63900000,
#      u'Liquor Laws',
#      u'SE ALDER ST and SE 3RD AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-WEST',
#      u'PORTLAND PREC CE',
#      u'711',
#      7647804.39024,
#      682350.11286],
#     [11620672,
#      1219118400000,
#      80280000,
#      u'Liquor Laws',
#      u'SE BELMONT ST and SE 11TH AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-WEST',
#      u'PORTLAND PREC CE',
#      u'711',
#      7649867.05905,
#      681764.99214],
#     [11135225,
#      1141880400000,
#      75720000,
#      u'Fraud',
#      u'9200-9378 block of SE DIVISION ST, PORTLAND, OR 97266',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'971',
#      7671799.2281,
#      676807.90095],
#     [11206555,
#      1160884800000,
#      26700000,
#      u'Assault, Simple',
#      u'1-99 block of NW 2ND AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645396.14405,
#      684306.47405],
#     [11166876,
#      1150516800000,
#      81600000,
#      u'Larceny',
#      u'601-699 block of SW 5TH AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644119.23119,
#      683005.45786],
#     [11659457,
#      1228194000000,
#      75900000,
#      u'Burglary',
#      u'3101-3299 block of NE 74TH AVE, PORTLAND, OR 97213',
#      u'ROSEWAY',
#      u'PORTLAND PREC NO',
#      u'642',
#      7667485.63714,
#      691540.63333],
#     [11192172,
#      1156219200000,
#      99540000,
#      u'Trespass',
#      u'2801-2849 block of N GANTENBEIN AVE, PORTLAND, OR 97227',
#      u'ELIOT',
#      u'PORTLAND PREC NO',
#      u'590',
#      7646337.98905,
#      691461.36071],
#     [11203742,
#      1159416000000,
#      75300000,
#      u'Larceny',
#      u'2200 Block NE 72nd Dr',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7666729.807,
#      689499.286],
#     [11133389,
#      1141362000000,
#      77400000,
#      u'Liquor Laws',
#      u'SW MORRISON ST and SW 10TH AVE, PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7642871.19119,
#      683235.22381],
#     [11584084,
#      1210478400000,
#      25860000,
#      u'Assault, Simple',
#      u'1300-1398 block of NW LOVEJOY ST, PORTLAND, OR 97209',
#      u'PEARL',
#      u'PORTLAND PREC CE',
#      u'821',
#      7642378.55714,
#      686912.79786],
#     [11127953,
#      1139979600000,
#      64800000,
#      u'Burglary',
#      u'700-798 block of NW 21ST AVE, PORTLAND, OR 97209',
#      u'NORTHWEST',
#      u'PORTLAND PREC CE',
#      u'810',
#      7639777.8219,
#      686133.195],
#     [11166797,
#      1149998400000,
#      22080000,
#      u'Trespass',
#      u'811-899 block of SE 3RD AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-WEST',
#      u'PORTLAND PREC CE',
#      u'711',
#      7647796.23524,
#      682090.2419],
#     [11204326,
#      1159502400000,
#      101760000,
#      u'DUII',
#      u'SW BARBUR BLVD and SW GIBBS ST, PORTLAND, OR 97239',
#      u'HOMESTEAD',
#      u'PORTLAND PREC CE',
#      u'871',
#      7643163.61524,
#      675722.15214],
#     [11551683,
#      1200027600000,
#      54000000,
#      u'Forgery',
#      u'5100-5228 block of NE 54TH AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7662287.13476,
#      697265.68786],
#     [11173271,
#      1151726400000,
#      67500000,
#      u'Disorderly Conduct',
#      u'SE HAWTHORNE BLVD and SE 37TH AVE, PORTLAND, OR 97214',
#      u'SUNNYSIDE',
#      u'PORTLAND PREC CE',
#      u'720',
#      7657217.7619,
#      679950.87476],
#     [11165194,
#      1149652800000,
#      55500000,
#      u'Fraud',
#      u'16040-16098 block of E BURNSIDE ST, PORTLAND, OR 97233',
#      u'GLENFAIR',
#      u'PORTLAND PREC EA',
#      u'961',
#      7689992.0969,
#      682818.31214],
#     [11150918,
#      1145937600000,
#      92400000,
#      u'Larceny',
#      u'MT TABOR PARK',
#      u'MT TABOR',
#      u'PORTLAND PREC EA',
#      u'902',
#      7664831.56828,
#      679365.67597],
#     [11589924,
#      1211947200000,
#      48600000,
#      u'Larceny',
#      u'3700-3798 block of SW US VETERANS HOSPITAL RD, PORTLAND, OR 97239',
#      u'HOMESTEAD',
#      u'PORTLAND PREC CE',
#      u'871',
#      7642429.83571,
#      674957.72071],
#     [11177030,
#      1153368000000,
#      75240000,
#      u'Forgery',
#      u'0-298 block of NW 20TH PL, PORTLAND, OR 97209',
#      u'NORTHWEST',
#      u'PORTLAND PREC CE',
#      u'810',
#      7640038.31381,
#      684461.20571],
#     [11192584,
#      1156478400000,
#      87240000,
#      u'Vandalism',
#      u'4800-4998 block of SE 28TH AVE, PORTLAND, OR 97202',
#      u'REED',
#      u'PORTLAND PREC CE',
#      u'741',
#      7653981.94286,
#      671333.88262],
#     [11122154,
#      1138424400000,
#      71160000,
#      u'Larceny',
#      u'SE STARK ST and SE 92ND AVE, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7671815.55976,
#      682130.77],
#     [11581318,
#      1209787200000,
#      49680000,
#      u'Embezzlement',
#      u'1701-1899 block of NE CESAR E CHAVEZ BLVD, PORTLAND, OR 97212',
#      u'HOLLYWOOD',
#      u'PORTLAND PREC NO',
#      u'680',
#      7658167.06119,
#      688350.37],
#     [11224333,
#      1165208400000,
#      98100000,
#      u'Trespass',
#      u'PIONEER SQUARE',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7643555.17863,
#      682817.95547],
#     [11161043,
#      1148961600000,
#      37560000,
#      u'Larceny',
#      u'7801-7899 block of NE HALSEY ST, PORTLAND, OR 97213',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'902',
#      7668379.72214,
#      687520.5931],
#     [11140044,
#      1143176400000,
#      31500000,
#      u'Trespass',
#      u'1900-1948 block of SW 6TH AVE, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642469.21548,
#      679745.94214],
#     [11559969,
#      1204434000000,
#      26280000,
#      u'Liquor Laws',
#      u'3500-3698 block of NE MARTIN LUTHER KING BLVD, PORTLAND, OR 97212',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648402.80405,
#      693395.71],
#     [11219541,
#      1163912400000,
#      96660000,
#      u'Larceny',
#      u'6101-6299 block of NE 21ST AVE, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7652950.25119,
#      700124.6819],
#     [11177712,
#      1153627200000,
#      20220000,
#      u'Larceny',
#      u'1101-1199 block of NW COUCH ST, PORTLAND, OR 97209',
#      u'PEARL',
#      u'PORTLAND PREC CE',
#      u'821',
#      7642898.06381,
#      684568.34238],
#     [11153040,
#      1146542400000,
#      52980000,
#      u'Larceny',
#      u'2900-3098 block of NE 15TH AVE, PORTLAND, OR 97212',
#      u'IRVINGTON',
#      u'PORTLAND PREC NO',
#      u'660',
#      7651215.83595,
#      691633.17286],
#     [11570614,
#      1207108800000,
#      67500000,
#      u'Larceny',
#      u'6631-6639 block of N OBERLIN ST, PORTLAND, OR 97203',
#      u'UNIVERSITY PARK',
#      u'PORTLAND PREC NO',
#      u'530',
#      7629818.13524,
#      707185.8281],
#     [11170625,
#      1151467200000,
#      86580000,
#      u'Forgery',
#      u'4300-4698 block of SW DICKINSON ST, PORTLAND, OR 97219',
#      u'W PORTLAND PARK',
#      u'PORTLAND PREC CE',
#      u'881',
#      7631890.63667,
#      657072.82714],
#     [11115694,
#      1136782800000,
#      83580000,
#      u'Larceny',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11195412,
#      1156305600000,
#      91320000,
#      u'Motor Vehicle Theft',
#      u'11838-12048 block of SW 49TH AVE, PORTLAND, OR 97219',
#      u'FAR SOUTHWEST',
#      u'PORTLAND PREC CE',
#      u'881',
#      7630317.74,
#      653999.57619],
#     [11545039,
#      1200546000000,
#      62700000,
#      u'Liquor Laws',
#      u'SW YAMHILL ST and SW 3RD AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644434.955,
#      682306.70571],
#     [11163827,
#      1149825600000,
#      22680000,
#      u'Drugs',
#      u'NW 4TH AVE and W BURNSIDE ST, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7644875.66405,
#      684308.09024],
#     [11140547,
#      1143435600000,
#      52320000,
#      u'Larceny',
#      u'601-699 block of SW 10TH AVE, PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7642970.17881,
#      683475.64524],
#     [11209860,
#      1161748800000,
#      76380000,
#      u'Motor Vehicle Theft',
#      u'SE FOSTER RD and SE 82ND AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'981',
#      7668952.1731,
#      668976.65119],
#     [11566067,
#      1205899200000,
#      80580000,
#      u'Vandalism',
#      u'1301-1399 block of NE BROADWAY , PORTLAND, OR 97232',
#      u'IRVINGTON',
#      u'PORTLAND PREC NO',
#      u'670',
#      7650598.81238,
#      688510.44333],
#     [11216456,
#      1163048400000,
#      63480000,
#      u'Larceny',
#      u'3500-3548 block of SE HAWTHORNE BLVD, PORTLAND, OR 97214',
#      u'RICHMOND',
#      u'PORTLAND PREC CE',
#      u'730',
#      7656602.84881,
#      679968.39381],
#     [11212613,
#      1162008000000,
#      24900000,
#      u'Liquor Laws',
#      u'SE POWELL BLVD and SE 82ND AVE, PORTLAND, OR 97266',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669152.3981,
#      674299.52238],
#     [11149777,
#      1145592000000,
#      94380000,
#      u'Disorderly Conduct',
#      u'WASHINGTON PARK TS',
#      u'SYLVAN-HIGHLNDS',
#      u'PORTLAND PREC CE',
#      u'860',
#      7633770.68703,
#      680060.41377],
#     [11655519,
#      1223524800000,
#      89940000,
#      u'Fraud',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11187133,
#      1155268800000,
#      88980000,
#      u'Larceny',
#      u'COLUMBIA PARK',
#      u'UNIVERSITY PARK',
#      u'PORTLAND PREC NO',
#      u'530',
#      7635507.35311,
#      704184.26496],
#     [11140571,
#      1143349200000,
#      56400000,
#      u'Trespass',
#      u'NW EVERETT ST and NW NAITO PKWY, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645954.18524,
#      685086.035],
#     [11225125,
#      1165726800000,
#      66000000,
#      u'Motor Vehicle Theft',
#      u'11101-11199 block of NE HANCOCK ST, PORTLAND, OR 97220',
#      u'PARKROSE HGTS',
#      u'PORTLAND PREC EA',
#      u'941',
#      7677109.93333,
#      688223.51976],
#     [11666410,
#      1230354000000,
#      88500000,
#      u'Prostitution',
#      u'SE CLAY ST and SE 82ND AVE, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669291.69714,
#      679441.305],
#     [11167271,
#      1150171200000,
#      50400000,
#      u'Vandalism',
#      u'700-798 block of SE 20TH AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-EAST',
#      u'PORTLAND PREC CE',
#      u'712',
#      7652217.1331,
#      682211.33429],
#     [11157529,
#      1147492800000,
#      72600000,
#      u'Disorderly Conduct',
#      u'801-899 block of SW MORRISON ST, PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7643255.16476,
#      683077.1419],
#     [11181804,
#      1153886400000,
#      86400000,
#      u'Trespass',
#      u'100-498 block of SE 160TH AVE, PORTLAND, OR 97233',
#      u'GLENFAIR',
#      u'PORTLAND PREC EA',
#      u'961',
#      7689796.97929,
#      682639.48833],
#     [11588581,
#      1211601600000,
#      27420000,
#      u'Burglary',
#      u'9001-9099 block of NE SANDY BLVD, PORTLAND, OR 97220',
#      u'SUMNER',
#      u'PORTLAND PREC NO',
#      u'642',
#      7671889.66786,
#      695560.8319],
#     [11219129,
#      1163826000000,
#      36900000,
#      u'Curfew',
#      u'SE POWELL BLVD and SE 174TH AVE, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7693214.84095,
#      671955.9719],
#     [11154169,
#      1146801600000,
#      68400000,
#      u'Larceny',
#      u'17000-17398 block of SE POWELL BLVD, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7692395.40833,
#      672089.48071],
#     [11158084,
#      1147838400000,
#      77220000,
#      u'Larceny',
#      u'1501-1699 block of NE 37TH AVE, PORTLAND, OR 97232',
#      u'SULLIVANS GULCH',
#      u'PORTLAND PREC NO',
#      u'680',
#      7657658.205,
#      687956.07571],
#     [11628786,
#      1221105600000,
#      51240000,
#      u'Larceny',
#      u'801-899 block of SE 29TH AVE, PORTLAND, OR 97214',
#      u'SUNNYSIDE',
#      u'PORTLAND PREC CE',
#      u'712',
#      7654634.80714,
#      681875.7869],
#     [11120304,
#      1137906000000,
#      74100000,
#      u'Larceny',
#      u'N ALTA AVE and N CRAWFORD ST, PORTLAND, OR 97203',
#      u'CATHEDRAL PARK',
#      u'PORTLAND PREC NO',
#      u'510',
#      7623533.14119,
#      708615.76119],
#     [11118813,
#      1137474000000,
#      98400000,
#      u'Larceny',
#      u'10000-10198 block of SE STARK ST, PORTLAND, OR 97216',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'951',
#      7674070.39905,
#      682063.88429],
#     [11211430,
#      1161576000000,
#      89640000,
#      u'Robbery',
#      u'NE MARTIN LUTHER KING BLVD and NE SKIDMORE ST, PORTLAND, OR 97211',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648477.16881,
#      695688.52524],
#     [11607119,
#      1216008000000,
#      50940000,
#      u'Vandalism',
#      u'900-998 block of NE 23RD AVE, PORTLAND, OR 97232',
#      u'KERNS',
#      u'PORTLAND PREC CE',
#      u'720',
#      7653132.05619,
#      686336.60071],
#     [11166812,
#      1150603200000,
#      27420000,
#      u'Motor Vehicle Theft',
#      u'SW MORRISON ST and SW 4TH AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644276.96595,
#      682656.46571],
#     [11188907,
#      1155700800000,
#      89880000,
#      u'Trespass',
#      u'NE PRESCOTT ST and NE 60TH AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7664024.80786,
#      695601.8019],
#     [11180898,
#      1153713600000,
#      73800000,
#      u'Liquor Laws',
#      u'SE STARK ST and SE 27TH AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-EAST',
#      u'PORTLAND PREC CE',
#      u'712',
#      7654087.17905,
#      682682.40714],
#     [11559316,
#      1204261200000,
#      57360000,
#      u'Larceny',
#      u'5700-5998 block of NE ALBERTA ST, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7663148.43571,
#      696960.09405],
#     [10923559,
#      1110690000000,
#      26700000,
#      u'Aggravated Assault',
#      u'NW COUCH ST and NW 1ST AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645656.28571,
#      684567.3781],
#     [11224757,
#      1165554000000,
#      81300000,
#      u'Larceny',
#      u'700 Block SW 5th Ave',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7643976.662,
#      682667.11],
#     [11206546,
#      1160193600000,
#      90600000,
#      u'Larceny',
#      u'4000 Block SE 82nd Ave',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669095.393,
#      672751.084],
#     [11636990,
#      1222747200000,
#      91680000,
#      u'Aggravated Assault',
#      u'3306-3398 block of NE 71ST AVE, PORTLAND, OR 97213',
#      u'ROSEWAY',
#      u'PORTLAND PREC NO',
#      u'680',
#      7666742.92238,
#      692378.52095],
#     [11113386,
#      1136005200000,
#      102000000,
#      u'Disorderly Conduct',
#      u'NW COUCH ST and NW 1ST AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645656.28571,
#      684567.3781],
#     [11221377,
#      1164517200000,
#      62220000,
#      u'Drugs',
#      u'NE KILLINGSWORTH ST and NE 105TH AVE, PORTLAND, OR 97220',
#      u'PARKROSE',
#      u'PORTLAND PREC NO',
#      u'651',
#      7675882.52571,
#      697036.86619],
#     [11188465,
#      1155614400000,
#      100800000,
#      u'Larceny',
#      u'5900-5998 block of NE MARTIN LUTHER KING BLVD, PORTLAND, OR 97211',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648616.47857,
#      699685.09214],
#     [11561839,
#      1204866000000,
#      82440000,
#      u'Vandalism',
#      u'122ND AVE TS',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'941',
#      7679720.08117,
#      683182.27355],
#     [10978049,
#      1123646400000,
#      45300000,
#      u'Disorderly Conduct',
#      u'100-198 block of SW 1ST AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645619.52524,
#      683790.51],
#     [11226417,
#      1165899600000,
#      55020000,
#      u'Larceny',
#      u'700-798 block of SW 3RD AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644535.90976,
#      682549.85714],
#     [11171913,
#      1151294400000,
#      104280000,
#      u'Vandalism',
#      u'1611-1899 block of NE 102ND AVE, PORTLAND, OR 97220',
#      u'WOODLAND PARK',
#      u'PORTLAND PREC EA',
#      u'941',
#      7674792.22929,
#      687643.69238],
#     [11651935,
#      1226379600000,
#      69840000,
#      u'Larceny',
#      u'1101-1299 block of SE 174TH AVE, PORTLAND, OR 97233',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'961',
#      7693400.38429,
#      680146.84786],
#     [11011786,
#      1132203600000,
#      24360000,
#      u'Trespass',
#      u'SW YAMHILL ST and SW 1ST AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644927.13881,
#      682107.64429],
#     [11156351,
#      1147320000000,
#      29400000,
#      u'DUII',
#      u'NE GRAND AVE and NE MASON ST, PORTLAND, OR 97211',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648717.73571,
#      695222.72405],
#     [11177904,
#      1152158400000,
#      97200000,
#      u'Liquor Laws',
#      u'101-199 block of W BURNSIDE ST, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645660.98643,
#      684293.62881],
#     [11564629,
#      1205553600000,
#      73620000,
#      u'Larceny',
#      u'NE KLICKITAT ST and NE 19TH AVE, PORTLAND, OR 97212',
#      u'SABIN',
#      u'PORTLAND PREC NO',
#      u'660',
#      7652310.62286,
#      692720.31095],
#     [11009556,
#      1131339600000,
#      96000000,
#      u'DUII',
#      u'NE HANCOCK ST and NE 2ND AVE, PORTLAND, OR 97212',
#      u'ELIOT',
#      u'PORTLAND PREC NO',
#      u'590',
#      7647756.57238,
#      689121.07976],
#     [11188160,
#      1155528000000,
#      82920000,
#      u'Larceny',
#      u'17050-17198 block of SE MAIN ST, PORTLAND, OR 97233',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'961',
#      7692391.50786,
#      679642.00667],
#     [11208480,
#      1160712000000,
#      57720000,
#      u'Larceny',
#      u'1001-1299 block of NE 102ND AVE, PORTLAND, OR 97220',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'941',
#      7674735.06024,
#      686008.53024],
#     [11569405,
#      1206763200000,
#      87780000,
#      u'DUII',
#      u'HAWTHORNE BRG EAST',
#      u'HOSFRD-ABRNETHY',
#      u'PORTLAND PREC CE',
#      u'730',
#      7646424.99,
#      680391.98],
#     [10995901,
#      1128139200000,
#      75060000,
#      u'Sex Offenses',
#      u'NW COUCH ST and NW 2ND AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645396.28619,
#      684567.63524],
#     [11170965,
#      1151121600000,
#      42960000,
#      u'Larceny',
#      u'2800-2898 block of SE 43RD AVE, PORTLAND, OR 97206',
#      u'RICHMOND',
#      u'PORTLAND PREC EA',
#      u'911',
#      7659128.9881,
#      676471.5131],
#     [11143169,
#      1144123200000,
#      78480000,
#      u'Larceny',
#      u'3930-4198 block of SE 97TH AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7672886.61,
#      672654.0931],
#     [11584519,
#      1210564800000,
#      69720000,
#      u'Vandalism',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11012144,
#      1131944400000,
#      69600000,
#      u'Vandalism',
#      u'200-298 block of NW 2ND AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645396.54405,
#      684827.63405],
#     [11206948,
#      1160884800000,
#      100260000,
#      u'Drugs',
#      u'SE DUKE ST and SE 82ND AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'990',
#      7668865.91929,
#      666778.49],
#     [11179621,
#      1153195200000,
#      97200000,
#      u'Fraud',
#      u'7201-7499 block of N INTERSTATE AVE, PORTLAND, OR 97217',
#      u'ARBOR LODGE',
#      u'PORTLAND PREC NO',
#      u'550',
#      7643417.09595,
#      703386.06119],
#     [11617467,
#      1218340800000,
#      75240000,
#      u'Vandalism',
#      u'NW DAVIS ST and NW 12TH AVE, PORTLAND, OR 97209',
#      u'PEARL',
#      u'PORTLAND PREC CE',
#      u'821',
#      7642635.97405,
#      684831.7319],
#     [10988309,
#      1126324800000,
#      53580000,
#      u'Larceny',
#      u'201-399 block of SE 2ND AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-WEST',
#      u'PORTLAND PREC CE',
#      u'711',
#      7647583.23619,
#      683660.3331],
#     [11214017,
#      1162357200000,
#      18360000,
#      u'Larceny',
#      u'6001-6199 block of SE BOISE ST, PORTLAND, OR 97206',
#      u'FOSTER-POWELL',
#      u'PORTLAND PREC EA',
#      u'911',
#      7663186.74167,
#      672606.54524],
#     [11230609,
#      1166936400000,
#      80400000,
#      u'DUII',
#      u'SW MARKET ST and SW NAITO PKWY, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7644390.265,
#      680069.20905],
#     [11659983,
#      1228280400000,
#      93600000,
#      u'Burglary',
#      u'1501-1699 block of N HOLMAN ST, PORTLAND, OR 97217',
#      u'ARBOR LODGE',
#      u'PORTLAND PREC NO',
#      u'570',
#      7643333.20905,
#      700875.49667],
#     [11005969,
#      1130644800000,
#      26280000,
#      u'Assault, Simple',
#      u'SW PINE ST and SW 2ND AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645280.53524,
#      683649.16119],
#     [11147288,
#      1145246400000,
#      68820000,
#      u'Forgery',
#      u'4273-4349 block of SE 82ND AVE, PORTLAND, OR 97266',
#      u'FOSTER-POWELL',
#      u'PORTLAND PREC EA',
#      u'912',
#      7669074.4219,
#      672113.93738],
#     [11208491,
#      1160712000000,
#      49740000,
#      u'Larceny',
#      u'2301-2399 block of SE 22ND AVE, PORTLAND, OR 97214',
#      u'HOSFRD-ABRNETHY',
#      u'PORTLAND PREC CE',
#      u'730',
#      7652720.0919,
#      677949.98524],
#     [11562505,
#      1205038800000,
#      87840000,
#      u'Liquor Laws',
#      u'SE BYBEE BLVD and SE 82ND AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'990',
#      7668824.31214,
#      665138.13167],
#     [10958781,
#      1119758400000,
#      26640000,
#      u'Aggravated Assault',
#      u'SW STARK ST and SW 2ND AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7645082.56595,
#      683168.31976],
#     [11222881,
#      1164862800000,
#      57600000,
#      u'Larceny',
#      u'3550-3748 block of SE 79TH AVE, PORTLAND, OR 97206',
#      u'FOSTER-POWELL',
#      u'PORTLAND PREC EA',
#      u'912',
#      7668163.01595,
#      674130.00167],
#     [11198604,
#      1158724800000,
#      81300000,
#      u'Drugs',
#      u'300-398 block of NW COUCH ST, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645136.28595,
#      684567.8931],
#     [11575867,
#      1208404800000,
#      94080000,
#      u'DUII',
#      u'SW JEFFERSON ST and SW 14TH AVE, PORTLAND, OR 97205',
#      u'GOOSE HOLLOW',
#      u'PORTLAND PREC CE',
#      u'841',
#      7641228.83881,
#      682216.42143],
#     [11010021,
#      1131858000000,
#      24780000,
#      u'Assault, Simple',
#      u'SW YAMHILL ST and SW 2ND AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644686.56786,
#      682206.68786],
#     [11193736,
#      1156996800000,
#      72300000,
#      u'Larceny',
#      u'2401-2499 block of NW RALEIGH ST, PORTLAND, OR 97210',
#      u'NORTHWEST',
#      u'PORTLAND PREC CE',
#      u'800',
#      7638220.14571,
#      688474.73405],
#     [11202211,
#      1158984000000,
#      32700000,
#      u'Burglary',
#      u'1600-1998 block of SE 41ST AVE, PORTLAND, OR 97214',
#      u'RICHMOND',
#      u'PORTLAND PREC EA',
#      u'901',
#      7658646.93595,
#      679637.92381],
#     [11617405,
#      1218340800000,
#      64980000,
#      u'Larceny',
#      u'3400-3498 block of NE 155TH AVE, PORTLAND, OR 97230',
#      u'WILKES',
#      u'PORTLAND PREC NO',
#      u'652',
#      7688973.7119,
#      692069.24071],
#     [10999629,
#      1129003200000,
#      80280000,
#      u'Fraud',
#      u'1101-1199 block of SW 2ND AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7644390.49881,
#      681485.01786],
#     [11161505,
#      1148788800000,
#      18000000,
#      u'Vandalism',
#      u'5500-5718 block of NE 60TH AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7664100.71619,
#      698260.48524],
#     [11134969,
#      1141966800000,
#      71220000,
#      u'Fraud',
#      u'8900-8998 block of N WALL AVE, PORTLAND, OR 97203',
#      u'PORTSMOUTH',
#      u'PORTLAND PREC NO',
#      u'530',
#      7631705.95214,
#      707763.6731],
#     [11625829,
#      1220414400000,
#      84660000,
#      u'Burglary',
#      u'850-898 block of SW 61ST DR, PORTLAND, OR 97221',
#      u'SYLVAN-HIGHLNDS',
#      u'PORTLAND PREC CE',
#      u'860',
#      7628098.72595,
#      682293.39429],
#     [11004832,
#      1130299200000,
#      98760000,
#      u'Larceny',
#      u'100-198 block of NE 3RD AVE, PORTLAND, OR 97232',
#      u'KERNS',
#      u'PORTLAND PREC CE',
#      u'711',
#      7647869.62429,
#      684429.08571],
#     [11137360,
#      1142485200000,
#      50700000,
#      u'Larceny',
#      u'600-698 block of SW ALDER ST, PORTLAND, OR 97205',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7643858.77143,
#      683110.73],
#     [11185191,
#      1154664000000,
#      90600000,
#      u'DUII',
#      u'NE ALBERTA ST and NE 42ND AVE, PORTLAND, OR 97218',
#      u'CULLY',
#      u'PORTLAND PREC NO',
#      u'641',
#      7659054.13119,
#      696987.25619],
#     [11663959,
#      1229317200000,
#      69300000,
#      u'Burglary',
#      u'4100-4298 block of N KERBY AVE, PORTLAND, OR 97217',
#      u'BOISE',
#      u'PORTLAND PREC NO',
#      u'580',
#      7645707.4769,
#      695309.09381],
#     [10987458,
#      1126065600000,
#      54900000,
#      u'Drugs',
#      u'NW COUCH ST and NW 3RD AVE, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645136.28595,
#      684567.8931],
#     [11195625,
#      1157428800000,
#      102000000,
#      u'Assault, Simple',
#      u'NE BROADWAY  and NE 84TH AVE, PORTLAND, OR 97220',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7670084.6369,
#      687976.61833],
#     [11146011,
#      1144728000000,
#      20520000,
#      u'Trespass',
#      u'SE POWELL BLVD and SE 33RD AVE, PORTLAND, OR 97202',
#      u'RICHMOND',
#      u'PORTLAND PREC CE',
#      u'730',
#      7655611.92571,
#      674427.33619],
#     [11610213,
#      1216699200000,
#      64140000,
#      u'Larceny',
#      u'12600-12798 block of SE ALDER ST, PORTLAND, OR 97233',
#      u'MILL PARK',
#      u'PORTLAND PREC EA',
#      u'952',
#      7681149.92881,
#      681035.64595],
#     [10945799,
#      1113883200000,
#      61200000,
#      u'Fraud',
#      u'301-399 block of SE 3RD AVE, PORTLAND, OR 97214',
#      u'BUCKMAN-WEST',
#      u'PORTLAND PREC CE',
#      u'711',
#      7647837.00786,
#      683389.59786],
#     [11144551,
#      1144296000000,
#      94500000,
#      u'Vandalism',
#      u'11201-11549 block of NE HOLMAN ST, PORTLAND, OR 97220',
#      u'PARKROSE',
#      u'PORTLAND PREC NO',
#      u'651',
#      7677823.32095,
#      699888.14619],
#     [11131790,
#      1141016400000,
#      64920000,
#      u'Burglary',
#      u'3500-3648 block of NE SANDY BLVD, PORTLAND, OR 97232',
#      u'LAURELHURST',
#      u'PORTLAND PREC CE',
#      u'720',
#      7656812.57571,
#      687497.6781],
#     [11586810,
#      1211169600000,
#      58800000,
#      u'Vandalism',
#      u'5201-5249 block of N WILLIAMS AVE, PORTLAND, OR 97217',
#      u'HUMBOLDT',
#      u'PORTLAND PREC NO',
#      u'580',
#      7647159.8731,
#      697893.20476],
#     [10999719,
#      1129348800000,
#      26880000,
#      u'Aggravated Assault',
#      u'SW STARK ST and SW 3RD AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644832.86714,
#      683271.12238],
#     [11170956,
#      1150862400000,
#      97740000,
#      u'Assault, Simple',
#      u'800-898 block of NE DEKUM ST, PORTLAND, OR 97211',
#      u'WOODLAWN',
#      u'PORTLAND PREC NO',
#      u'610',
#      7649720.77476,
#      701933.38762],
#     [11228653,
#      1166504400000,
#      67080000,
#      u'Vandalism',
#      u'3900-3998 block of SE POWELL BLVD, PORTLAND, OR 97202',
#      u'CRSTN-KENILWTH',
#      u'PORTLAND PREC EA',
#      u'911',
#      7657898.8269,
#      674564.53881],
#     [11651177,
#      1226120400000,
#      99300000,
#      u'Prostitution',
#      u'4000-4098 block of SE 82ND AVE, PORTLAND, OR 97266',
#      u'LENTS',
#      u'PORTLAND PREC EA',
#      u'971',
#      7669098.595,
#      672852.01786],
#     [10990266,
#      1126756800000,
#      80520000,
#      u'Larceny',
#      u'SW ALDER ST and SW 3RD AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644634.89929,
#      682790.27905],
#     [11150958,
#      1146283200000,
#      30840000,
#      u'Vandalism',
#      u'400-698 block of NE COOK ST, PORTLAND, OR 97212',
#      u'ELIOT',
#      u'PORTLAND PREC NO',
#      u'590',
#      7648389.77071,
#      692993.37214],
#     [11161040,
#      1148702400000,
#      19920000,
#      u'Liquor Laws',
# ...
#      46860000,
#      u'Burglary',
#      u'1-199 block of SE 80TH AVE, PORTLAND, OR 97215',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'902',
#      7668682.5531,
#      683571.65833],
#     [11628628,
#      1221019200000,
#      99660000,
#      u'Weapons',
#      u'N MISSISSIPPI AVE and N RUSSET ST, PORTLAND, OR 97217',
#      u'PIEDMONT',
#      u'PORTLAND PREC NO',
#      u'560',
#      7644918.5769,
#      704312.06095],
#     [11166324,
#      1149825600000,
#      68580000,
#      u'Larceny',
#      u'1000-1298 block of NE 102ND AVE, PORTLAND, OR 97220',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'941',
#      7674735.06024,
#      686008.53024],
#     [11448413,
#      1173844800000,
#      58200000,
#      u'Larceny',
#      u'1000-1298 block of NE 102ND AVE, PORTLAND, OR 97220',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'941',
#      7674735.06024,
#      686008.53024],
#     [11206127,
#      1160107200000,
#      33600000,
#      u'DUII',
#      u'SE CESAR E CHAVEZ BLVD and SE GRANT ST, PORTLAND, OR 97214',
#      u'RICHMOND',
#      u'PORTLAND PREC EA',
#      u'901',
#      7657972.24095,
#      678285.27214],
#     [11569671,
#      1206849600000,
#      83460000,
#      u'Vandalism',
#      u'NE ALAMEDA ST and NE 52ND AVE, PORTLAND, OR 97213',
#      u'ROSE CITY PARK',
#      u'PORTLAND PREC NO',
#      u'680',
#      7661636.70214,
#      690745.91095],
#     [11185640,
#      1154923200000,
#      56580000,
#      u'Larceny',
#      u'1501-1599 block of SW PARK AVE, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642329.33905,
#      681204.94429],
#     [11441776,
#      1172120400000,
#      77160000,
#      u'Larceny',
#      u'7901-7999 block of SE POWELL BLVD, PORTLAND, OR 97206',
#      u'SOUTH TABOR',
#      u'PORTLAND PREC EA',
#      u'912',
#      7668164.47333,
#      674326.76667],
#     [11117143,
#      1136869200000,
#      84900000,
#      u'Larceny',
#      u'601-699 block of SW MONTGOMERY ST, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642667.32214,
#      680227.08381],
#     [11543011,
#      1199682000000,
#      23520000,
#      u'Aggravated Assault',
#      u'3000-3098 block of SE POWELL BLVD, PORTLAND, OR 97202',
#      u'CRSTN-KENILWTH',
#      u'PORTLAND PREC CE',
#      u'741',
#      7654838.82881,
#      674561.81405],
#     [11136232,
#      1142226000000,
#      33240000,
#      u'Larceny',
#      u'13421-13599 block of SE POWELL BLVD, PORTLAND, OR 97236',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'972',
#      7682863.4931,
#      674011.97929],
#     [11365851,
#      1182139200000,
#      102960000,
#      u'Forgery',
#      u'SE FLAVEL ST and SE 72ND AVE, PORTLAND, OR 97206',
#      u'BRENTWD-DARLNGT',
#      u'PORTLAND PREC EA',
#      u'923',
#      7666151.67905,
#      663887.73571],
#     [11179694,
#      1153281600000,
#      70620000,
#      u'Liquor Laws',
#      u'SOUTH PARK BLOCKS',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7642731.62709,
#      682030.08641],
#     [11628430,
#      1221019200000,
#      67800000,
#      u'Larceny',
#      u'8500-8588 block of NE GLISAN ST, PORTLAND, OR 97220',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7670121.7031,
#      684848.08786],
#     [11129550,
#      1140411600000,
#      101400000,
#      u'Assault, Simple',
#      u'12421-12529 block of SE POWELL BLVD, PORTLAND, OR 97236',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'972',
#      7680272.34405,
#      673922.28071],
#     [11344751,
#      1177646400000,
#      81420000,
#      u'Vandalism',
#      u'2501-2599 block of SE HAWTHORNE BLVD, PORTLAND, OR 97214',
#      u'BUCKMAN-EAST',
#      u'PORTLAND PREC CE',
#      u'712',
#      7653501.5669,
#      680057.48881],
#     [11133893,
#      1141707600000,
#      18420000,
#      u'Drugs',
#      u'N KILLINGSWORTH ST and N WILLIAMS AVE, PORTLAND, OR 97217',
#      u'HUMBOLDT',
#      u'PORTLAND PREC NO',
#      u'580',
#      7647178.08071,
#      698696.26881],
#     [11563146,
#      1205208000000,
#      68280000,
#      u'Burglary',
#      u'2401-2419 block of NE ALBERTA ST, PORTLAND, OR 97211',
#      u'CONCORDIA',
#      u'PORTLAND PREC NO',
#      u'620',
#      7653796.815,
#      697185.32905],
#     [11149430,
#      1145592000000,
#      48540000,
#      u'Burglary',
#      u'6251-6399 block of SW CAPITOL HWY, PORTLAND, OR 97239',
#      u'HILLSDALE',
#      u'PORTLAND PREC CE',
#      u'882',
#      7639545.62976,
#      668268.08905],
#     [11442907,
#      1172466000000,
#      63600000,
#      u'Larceny',
#      u'401-499 block of SW WASHINGTON ST, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644474.93976,
#      683137.3069],
#     [11151602,
#      1146542400000,
#      27960000,
#      u'Drugs',
#      u'1850-1898 block of SW 5TH AVE, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642828.16786,
#      679877.36],
#     [11587918,
#      1211428800000,
#      54540000,
#      u'Trespass',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11119691,
#      1137819600000,
#      83940000,
#      u'Trespass',
#      u'1501-1669 block of NE 40TH AVE, PORTLAND, OR 97232',
#      u'HOLLYWOOD',
#      u'PORTLAND PREC NO',
#      u'680',
#      7658335.27929,
#      687860.0619],
#     [11410021,
#      1191902400000,
#      70260000,
#      u'Larceny',
#      u'1300-1398 block of W BURNSIDE ST, PORTLAND, OR 97209',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'842',
#      7642381.71381,
#      684316.75548],
#     [11218746,
#      1163653200000,
#      95400000,
#      u'Larceny',
#      u'301-399 block of NW 9TH AVE, PORTLAND, OR 97209',
#      u'PEARL',
#      u'PORTLAND PREC CE',
#      u'821',
#      7643416.79762,
#      685089.59405],
#     [11578400,
#      1209096000000,
#      68400000,
#      u'Embezzlement',
#      u'400-498 block of W BURNSIDE ST, PORTLAND, OR 97209',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7644875.66405,
#      684308.09024],
#     [11212377,
#      1161662400000,
#      86400000,
#      u'Larceny',
#      u'1701-1879 block of SW PARK AVE, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642132.04119,
#      680727.86595],
#     [11339891,
#      1176609600000,
#      55680000,
#      u'Motor Vehicle Theft',
#      u'4101-4299 block of NE 82ND AVE, PORTLAND, OR 97220',
#      u'ROSEWAY',
#      u'PORTLAND PREC NO',
#      u'642',
#      7669676.5819,
#      694352.3231],
#     [11121201,
#      1138078800000,
#      69120000,
#      u'Larceny',
#      u'701-899 block of NE MULTNOMAH ST, PORTLAND, OR 97232',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7648998.22857,
#      687261.17333],
#     [11601137,
#      1214539200000,
#      75300000,
#      u'Larceny',
#      u'14554-14798 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7685959.62857,
#      676346.42786],
#     [11121766,
#      1138338000000,
#      29400000,
#      u'Burglary',
#      u'8401-8449 block of SW MACADAM AVE, PORTLAND, OR 97219',
#      u'',
#      u'PORTLAND PREC CE',
#      u'890',
#      7645637.95786,
#      662938.53429],
#     [11352914,
#      1179374400000,
#      94260000,
#      u'Liquor Laws',
#      u'7801-8019 block of SE 65TH AVE, PORTLAND, OR 97206',
#      u'BRENTWD-DARLNGT',
#      u'PORTLAND PREC EA',
#      u'923',
#      7664217.65143,
#      663473.76286],
#     [11116625,
#      1136869200000,
#      96120000,
#      u'Larceny',
#      u'3201-3299 block of SE ALDER CT, PORTLAND, OR 97214',
#      u'SUNNYSIDE',
#      u'PORTLAND PREC CE',
#      u'720',
#      7655608.80929,
#      682230.17381],
#     [11665435,
#      1229922000000,
#      24360000,
#      u'Weapons',
#      u'N FESSENDEN ST and N TIOGA AVE, PORTLAND, OR 97203',
#      u'ST JOHNS',
#      u'PORTLAND PREC NO',
#      u'520',
#      7628487.0719,
#      710940.31381],
#     [11169446,
#      1150689600000,
#      84240000,
#      u'Larceny',
#      u'9000-9198 block of NE MARTIN LUTHER KING BLVD, PORTLAND, OR 97211',
#      u'E COLUMBIA',
#      u'PORTLAND PREC NO',
#      u'540',
#      7647967.91071,
#      707833.35762],
#     [11378735,
#      1184904000000,
#      76680000,
#      u'Vandalism',
#      u'2201-2499 block of SE 142ND AVE, PORTLAND, OR 97233',
#      u'HAZELWOOD',
#      u'PORTLAND PREC EA',
#      u'952',
#      7684985.50881,
#      677324.31286],
#     [11172586,
#      1152158400000,
#      42420000,
#      u'Burglary',
#      u'8200-8398 block of SE TAYLOR ST, PORTLAND, OR 97216',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669279.98119,
#      680887.07405],
#     [11571562,
#      1207281600000,
#      26580000,
#      u'Assault, Simple',
#      u'14220-14278 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7685025.27905,
#      676349.38071],
#     [11195012,
#      1156996800000,
#      89400000,
#      u'Disorderly Conduct',
#      u'14800-15098 block of E BURNSIDE ST, PORTLAND, OR 97233',
#      u'GLENFAIR',
#      u'PORTLAND PREC EA',
#      u'961',
#      7686821.25214,
#      682930.90405],
#     [11423360,
#      1195102800000,
#      81000000,
#      u'Fraud',
#      u'2500-2598 block of NE 82ND AVE, PORTLAND, OR 97220',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7669493.73167,
#      689856.78571],
#     [11148398,
#      1145246400000,
#      63000000,
#      u'Vandalism',
#      u'1900-1948 block of SW 6TH AVE, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642469.21548,
#      679745.94214],
#     [11657814,
#      1227762000000,
#      91800000,
#      u'Disorderly Conduct',
#      u'HOLLYWOOD TC',
#      u'HOLLYWOOD',
#      u'PORTLAND PREC NO',
#      u'680',
#      7658730.57862,
#      687651.14677],
#     [11141339,
#      1143522000000,
#      41700000,
#      u'Trespass',
#      u'301-399 block of NW GLISAN ST, PORTLAND, OR 97209',
#      u'CHINA/OLD TOWN',
#      u'PORTLAND PREC CE',
#      u'822',
#      7645134.19095,
#      685650.7269],
#     [11330531,
#      1171342800000,
#      52680000,
#      u'Fraud',
#      u'1300 Block NE 9th Ave',
#      u'LLOYD',
#      u'PORTLAND PREC NO',
#      u'690',
#      7649534.566,
#      687622.382],
#     [11210148,
#      1161835200000,
#      62400000,
#      u'Fraud',
#      u'16600-16648 block of SE HAIG DR, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7691375.3781,
#      673745.0219],
#     [11582728,
#      1210132800000,
#      24300000,
#      u'Prostitution',
#      u'E BURNSIDE ST and NE 83RD AVE, PORTLAND, OR 97220',
#      u'MONTAVILLA',
#      u'PORTLAND PREC EA',
#      u'932',
#      7669560.48619,
#      683539.53619],
#     [11217654,
#      1163394000000,
#      64800000,
#      u'Larceny',
#      u'1501-1599 block of NE 92ND AVE, PORTLAND, OR 97220',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7672090.35024,
#      687371.46881],
#     [11452435,
#      1174708800000,
#      100980000,
#      u'Larceny',
#      u'900-998 block of SW MILL ST, PORTLAND, OR 97201',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'850',
#      7642132.04119,
#      680727.86595],
#     [11156353,
#      1147406400000,
#      90360000,
#      u'Larceny',
#      u'N INTERSTATE AVE and N LOMBARD ST, PORTLAND, OR 97217',
#      u'KENTON',
#      u'PORTLAND PREC NO',
#      u'560',
#      7643436.90524,
#      704053.33405],
#     [11659821,
#      1228280400000,
#      67800000,
#      u'Forgery',
#      u'10201-10399 block of SE WASHINGTON ST, PORTLAND, OR 97216',
#      u'MILL PARK',
#      u'PORTLAND PREC EA',
#      u'951',
#      7674542.38286,
#      681794.97071],
#     [11163241,
#      1149134400000,
#      91440000,
#      u'Burglary',
#      u'7501-7511 block of SE 120TH PL, PORTLAND, OR 97266',
#      u'PLEASANT VALLEY',
#      u'PORTLAND PREC EA',
#      u'990',
#      7679290.3431,
#      663495.54381],
#     [11320282,
#      1168405200000,
#      36120000,
#      u'Drugs',
#      u'SW ALDER ST and SW 6TH AVE, PORTLAND, OR 97204',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7643858.77143,
#      683110.73],
#     [11116979,
#      1137128400000,
#      84360000,
#      u'Motor Vehicle Theft',
#      u'2500-2698 block of SE 157TH AVE, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7688948.625,
#      676362.58167],
#     [11610118,
#      1216699200000,
#      45300000,
#      u'Larceny',
#      u'NW COUCH ST and NW 14TH AVE, PORTLAND, OR 97209',
#      u'PEARL',
#      u'PORTLAND PREC CE',
#      u'821',
#      7642119.93381,
#      684569.8731],
#     [11178808,
#      1153108800000,
#      98100000,
#      u'Assault, Simple',
#      u'17431-17479 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'961',
#      7693650.50071,
#      676299.84024],
#     [11321400,
#      1168491600000,
#      85440000,
#      u'Larceny',
#      u'700 Block SW 5th Ave',
#      u'DOWNTOWN',
#      u'PORTLAND PREC CE',
#      u'830',
#      7643976.662,
#      682667.11],
#     [11170368,
#      1151553600000,
#      28740000,
#      u'Aggravated Assault',
#      u'2001-2099 block of NW IRVING ST, PORTLAND, OR 97209',
#      u'NORTHWEST',
#      u'PORTLAND PREC CE',
#      u'810',
#      7640297.8231,
#      686132.6819],
#     [11563995,
#      1205380800000,
#      90660000,
#      u'Larceny',
#      u'4300-4498 block of NE 76TH AVE, PORTLAND, OR 97218',
#      u'ROSEWAY',
#      u'PORTLAND PREC NO',
#      u'642',
#      7668140.01476,
#      694906.0381],
#     [11155441,
#      1147406400000,
#      65400000,
#      u'Drugs',
#      u'NE LLOYD BLVD and NE 11TH AVE, PORTLAND, OR 97232',
#      u'SULLIVANS GULCH',
#      u'PORTLAND PREC NO',
#      u'690',
#      7650072.91,
#      686347.0131],
#     [11439850,
#      1171256400000,
#      50040000,
#      u'Larceny',
#      u'5401-5599 block of SE FRANCIS ST, PORTLAND, OR 97206',
#      u'FOSTER-POWELL',
#      u'PORTLAND PREC EA',
#      u'911',
#      7661817.875,
#      673521.96881],
#     [11187371,
#      1155268800000,
#      72960000,
#      u'Larceny',
#      u'4701-4799 block of SE DIVISION ST, PORTLAND, OR 97206',
#      u'RICHMOND',
#      u'PORTLAND PREC EA',
#      u'901',
#      7660153.37119,
#      677407.6481],
#     [11559201,
#      1204174800000,
#      78600000,
#      u'Trespass',
#      u'2800-2898 block of SE 127TH AVE, PORTLAND, OR 97236',
#      u'POWELHST-GILBRT',
#      u'PORTLAND PREC EA',
#      u'972',
#      7681029.685,
#      675594.73167],
#     [11196163,
#      1157515200000,
#      65160000,
#      u'Drugs',
#      u'CLINTON PARK',
#      u'SOUTH TABOR',
#      u'PORTLAND PREC EA',
#      u'911',
#      7662195.70382,
#      676625.9755],
#     [11341192,
#      1176868800000,
#      79800000,
#      u'Larceny',
#      u'14554-14798 block of SE DIVISION ST, PORTLAND, OR 97236',
#      u'CENTENNIAL',
#      u'PORTLAND PREC EA',
#      u'962',
#      7685959.62857,
#      676346.42786],
#     [11139690,
#      1143090000000,
#      64020000,
#      u'Fraud',
#      u'400-498 block of NE MASON ST, PORTLAND, OR 97211',
#      u'KING',
#      u'PORTLAND PREC NO',
#      u'630',
#      7648462.48357,
#      695233.7531],
#     [11551612,
#      1202360400000,
#      51360000,
#      u'Motor Vehicle Theft',
#      u'12600-12798 block of SE ALDER ST, PORTLAND, OR 97233',
#      u'MILL PARK',
#      u'PORTLAND PREC EA',
#      u'952',
#      7681149.92881,
#      681035.64595],
#     [11181888,
#      1153886400000,
#      82800000,
#      u'Disorderly Conduct',
#      u'DAWSON PARK',
#      u'ELIOT',
#      u'PORTLAND PREC NO',
#      u'590',
#      7646961.42774,
#      691946.60317],
#     [11344619,
#      1177646400000,
#      81000000,
#      u'Motor Vehicle Theft',
#      u'SE CESAR E CHAVEZ BLVD and SE FRANKLIN ST, PORTLAND, OR 97202',
#      u'RICHMOND',
#      u'PORTLAND PREC EA',
#      u'911',
#      7657910.15119,
#      675201.21024],
#     [11126095,
#      1139547600000,
#      97200000,
#      u'DUII',
#      u'2600-2848 block of NE 82ND AVE, PORTLAND, OR 97220',
#      u'MADISON SOUTH',
#      u'PORTLAND PREC EA',
#      u'931',
#      7669509.35238,
#      690138.05714],
#     [11628324,
#      1221019200000,
#      51960000,
#      u'Larceny',
#      u'3600-3698 block of SE WOODWARD ST, PORTLAND, OR 97202',
#      u'RICHMOND',
#      u'PORTLAND PREC CE',
#      u'730',
#      7657012.74095,
#      676266.06214],
#     [11205072,
#      1159848000000,
#      85740000,
#      u'Larceny',
#      u'2600 Block SE Bybee Blvd',
#      u'EASTMORELAND',
#      u'PORTLAND PREC CE',
#      u'742',
#      7653871.596,
#      666293.9500000001]],
#    u'resultSet': True,
#    u'rowCount': 1000,
#    u'rowLimitExceeded': True}]}

# %%
data = ret['results'][0]['data']

# %%
crime_by_zipcode = {}
for i in range(0, len(data)):
    zipcode = data[i][4][-5:]
    try:
        zipcode = int(zipcode)
        if zipcode not in crime_by_zipcode:
            crime_by_zipcode[zipcode] = []
        t_data = []
        t_data.append(data[i][3])
        t_data.append(data[i][8])
        t_data.append(data[i][9])
        crime_by_zipcode[zipcode].append(t_data)
    except:
        pass

# %%
crime_by_zipcode
# Out:
# {97201: [[u'Larceny', 7635511.10976, 677887.12976],
#   [u'Trespass', 7642469.21548, 679745.94214],
#   [u'DUII', 7644390.265, 680069.20905],
